# %%
import pandas as pd
import numpy as np
import re
import dateparser
from collections import Counter
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
def read_file(file):
 x = open(file,'r', encoding = 'utf-8')
 y = x.read()
 content = y.splitlines()
 return content

# %%
chat = read_file('Chat.txt')
len(chat)
# Out:
# 12381

# %%
join = [line for line in chat if  "joined using this" in line]
print (join)
# Out:
# []

# %%
chat = [line.strip() for line in chat]
print("length of chat is:")
print(len(chat))
# Out:
# length of chat is:
# 12381

# %%
clean_chat = [line for line in chat if not "joined using this" in line]

# %%
clean_chat = [line for line in clean_chat if len(line) > 1]
print("length of clean_chat is:")
print(len(clean_chat))
# Out:
# length of clean_chat is:
# 10877

# %%
left = [line for line in clean_chat if line.endswith("left")]
left
# Out:
# ['11/02/2020, 7:40 pm - Tobi Lasu left',
#  '12/03/2020, 2:34 pm - Funmi Lasu left',
#  '15/03/2020, 12:56 am - Tunde Lasu left',
#  '20/03/2020, 9:51 pm - +234 808 098 4556 left',
#  "31/03/2020, 8:47 pm - Adam's Lasu left",
#  '31/03/2020, 8:48 pm - Kaydee left',
#  '31/03/2020, 8:50 pm - Musti left',
#  '31/03/2020, 8:51 pm - Atumo left',
#  '31/03/2020, 8:52 pm - +234 706 380 8118 left',
#  '02/04/2020, 11:40 pm - Dayo left',
#  '10/04/2020, 5:59 pm - Abraham left',
#  '29/04/2020, 7:28 pm - Musti 2 left',
#  '06/05/2020, 6:08 pm - Uche Physics left',
#  '11/05/2020, 5:46 pm - Teejay left',
#  '13/05/2020, 7:35 pm - +234 906 063 6950 left',
#  '26/05/2020, 3:53 pm - Mayowa 2 left']

# %%
clean_chat = [line for line in clean_chat if not line.endswith("left")]
print(len(clean_chat))
# Out:
# 10861

# %%
msgs = [] #message container
pos = 0 #counter for position of msgs in the container
"""
Flow:
For every line, see if it matches the expression which is starting with the format "number(s)+slash" eg "12/"
If it does, it is a new line of conversion as they begin with dates, add it to msgs container
Else, it is a continuation of the previous line, add it to the previous line and append to msgs, then pop previous line.
"""
for line in clean_chat:
    if re.findall("\A\d+[/]", line):
        msgs.append(line)
        pos += 1
    else:
        take = msgs[pos-1] + ". " + line
        msgs.append(take)
        msgs.pop(pos-1)
len(msgs)
# Out:
# 8072

# %%
msgs[0:10]
# Out:
# ['31/01/2020, 11:57 am - Sonia Blade created group "400l physicists⚖📡🗜⚡"',
#  '31/01/2020, 11:57 am - You were added',
#  '04/02/2020, 7:14 am - Funmi Lasu 2: Will yhu guys jus stop all memes u guys are doing, at ur age una still dey gt time to beef or fight... Una no wise at all',
#  '04/02/2020, 7:14 am - Funmi Lasu 2: Sorry dear',
#  '04/02/2020, 7:14 am - Funmi Lasu 2: Make una beta go sleep',
#  '04/02/2020, 7:14 am - Funmi Lasu 2: <Media omitted>',
#  '04/02/2020, 8:03 am - Aisha: Sorry. Get well soon',
#  "04/02/2020, 8:03 am - Aisha: Please who else did they tell we ain't supposed to come for ent tomorrow again",
#  '04/02/2020, 8:03 am - Aisha: Okay na',
#  '04/02/2020, 8:03 am - Aisha: Cos they said they told them not to come tomorrow. That tomorrow is for epe people and ikeja maybr']

# %%
time = [msgs[i].split(',')[1].split('-')[0] for i in range(len(msgs))]
time = [s.strip(' ') for s in time] # Remove spacing
print("length of time is:")
print(len(time))
time
# Out:
# length of time is:
# 8072
# ['11:57 am',
#  '11:57 am',
#  '7:14 am',
#  '7:14 am',
#  '7:14 am',
#  '7:14 am',
#  '8:03 am',
#  '8:03 am',
#  '8:03 am',
#  '8:03 am',
#  '8:03 am',
#  '8:04 am',
#  '8:04 am',
#  '8:04 am',
#  '8:04 am',
#  '8:54 am',
#  '11:47 am',
#  '11:48 am',
#  '11:48 am',
#  '11:49 am',
#  '11:50 am',
#  '11:50 am',
#  '11:52 am',
#  '11:52 am',
#  '12:03 pm',
#  '12:03 pm',
#  '12:04 pm',
#  '12:12 pm',
#  '12:13 pm',
#  '9:11 am',
#  '9:11 am',
#  '9:12 am',
#  '9:13 am',
#  '9:13 am',
#  '9:13 am',
#  '9:15 am',
#  '9:23 am',
#  '9:42 am',
#  '9:43 am',
#  '9:48 am',
#  '11:04 am',
#  '11:39 am',
#  '12:16 pm',
#  '12:28 pm',
#  '2:51 pm',
#  '2:54 pm',
#  '3:10 pm',
#  '3:19 pm',
#  '10:46 pm',
#  '10:51 pm',
#  '10:51 pm',
#  '10:52 pm',
#  '10:52 pm',
#  '10:52 pm',
#  '10:52 pm',
#  '10:53 pm',
#  '11:00 pm',
#  '11:04 pm',
#  '11:04 pm',
#  '11:04 pm',
#  '11:05 pm',
#  '11:05 pm',
#  '11:05 pm',
#  '11:06 pm',
#  '11:06 pm',
#  '11:06 pm',
#  '11:06 pm',
#  '11:06 pm',
#  '11:06 pm',
#  '11:07 pm',
#  '11:07 pm',
#  '11:07 pm',
#  '11:09 pm',
#  '11:10 pm',
#  '1:40 pm',
#  '1:40 pm',
#  '1:41 pm',
#  '1:42 pm',
#  '1:46 pm',
#  '1:50 pm',
#  '2:27 pm',
#  '2:27 pm',
#  '2:49 pm',
#  '2:49 pm',
#  '2:54 pm',
#  '2:57 pm',
#  '2:57 pm',
#  '2:58 pm',
#  '3:04 pm',
#  '3:58 pm',
#  '8:59 pm',
#  '10:21 pm',
#  '10:21 pm',
#  '10:22 pm',
#  '10:23 pm',
#  '10:23 pm',
#  '10:23 pm',
#  '10:25 pm',
#  '10:25 pm',
#  '10:26 pm',
#  '10:26 pm',
#  '10:27 pm',
#  '10:27 pm',
#  '10:29 pm',
#  '10:29 pm',
#  '10:29 pm',
#  '10:30 pm',
#  '10:30 pm',
#  '10:31 pm',
#  '10:31 pm',
#  '10:45 pm',
#  '10:46 pm',
#  '10:46 pm',
#  '10:46 pm',
#  '10:48 pm',
#  '10:48 pm',
#  '10:49 pm',
#  '10:49 pm',
#  '10:50 pm',
#  '10:51 pm',
#  '10:52 pm',
#  '10:55 pm',
#  '10:56 pm',
#  '10:58 pm',
#  '10:58 pm',
#  '11:00 pm',
#  '11:01 pm',
#  '11:02 pm',
#  '8:33 am',
#  '8:34 am',
#  '8:34 am',
#  '8:37 am',
#  '8:40 am',
#  '8:40 am',
#  '10:46 am',
#  '10:49 am',
#  '1:18 pm',
#  '1:19 pm',
#  '1:20 pm',
#  '1:20 pm',
#  '1:21 pm',
#  '1:21 pm',
#  '1:21 pm',
#  '1:21 pm',
#  '1:21 pm',
#  '1:21 pm',
#  '1:21 pm',
#  '1:21 pm',
#  '1:22 pm',
#  '1:23 pm',
#  '1:24 pm',
#  '1:25 pm',
#  '1:25 pm',
#  '1:25 pm',
#  '1:26 pm',
#  '1:26 pm',
#  '1:26 pm',
#  '1:28 pm',
#  '1:28 pm',
#  '1:30 pm',
#  '1:31 pm',
#  '1:32 pm',
#  '1:32 pm',
#  '1:34 pm',
#  '1:34 pm',
#  '1:36 pm',
#  '1:37 pm',
#  '1:37 pm',
#  '1:49 pm',
#  '1:49 pm',
#  '1:55 pm',
#  '2:06 pm',
#  '2:14 pm',
#  '2:39 pm',
#  '3:53 pm',
#  '9:45 pm',
#  '9:49 pm',
#  '6:10 am',
#  '7:20 am',
#  '7:50 am',
#  '8:03 am',
#  '8:03 am',
#  '8:03 am',
#  '8:04 am',
#  '8:20 am',
#  '11:48 am',
#  '1:22 pm',
#  '1:30 pm',
#  '1:31 pm',
#  '1:31 pm',
#  '1:41 pm',
#  '1:41 pm',
#  '1:42 pm',
#  '1:42 pm',
#  '1:44 pm',
#  '1:53 pm',
#  '1:58 pm',
#  '2:31 pm',
#  '2:51 pm',
#  '3:14 pm',
#  '3:38 pm',
#  '3:40 pm',
#  '3:41 pm',
#  '3:45 pm',
#  '3:58 pm',
#  '5:07 pm',
#  '6:11 pm',
#  '6:12 pm',
#  '6:13 pm',
#  '6:13 pm',
#  '6:15 pm',
#  '8:00 pm',
#  '8:05 pm',
#  '8:06 pm',
#  '8:06 pm',
#  '8:06 pm',
#  '8:06 pm',
#  '8:07 pm',
#  '8:07 pm',
#  '8:08 pm',
#  '8:08 pm',
#  '8:09 pm',
#  '8:09 pm',
#  '8:10 pm',
#  '8:12 pm',
#  '8:14 pm',
#  '8:16 pm',
#  '8:16 pm',
#  '8:17 pm',
#  '8:17 pm',
#  '8:17 pm',
#  '8:17 pm',
#  '8:18 pm',
#  '8:18 pm',
#  '8:18 pm',
#  '8:19 pm',
#  '8:19 pm',
#  '8:19 pm',
#  '8:19 pm',
#  '8:20 pm',
#  '8:20 pm',
#  '8:21 pm',
#  '8:21 pm',
#  '8:21 pm',
#  '8:22 pm',
#  '8:22 pm',
#  '8:22 pm',
#  '8:22 pm',
#  '8:23 pm',
#  '8:23 pm',
#  '8:23 pm',
#  '8:23 pm',
#  '8:24 pm',
#  '8:24 pm',
#  '8:24 pm',
#  '8:24 pm',
#  '8:24 pm',
#  '8:24 pm',
#  '8:24 pm',
#  '8:25 pm',
#  '8:25 pm',
#  '8:25 pm',
#  '8:33 pm',
#  '9:13 pm',
#  '9:14 pm',
#  '9:14 pm',
#  '9:14 pm',
#  '9:15 pm',
#  '9:15 pm',
#  '9:16 pm',
#  '9:22 pm',
#  '9:23 pm',
#  '9:25 pm',
#  '9:25 pm',
#  '9:26 pm',
#  '9:26 pm',
#  '9:26 pm',
#  '9:26 pm',
#  '9:27 pm',
#  '9:27 pm',
#  '9:27 pm',
#  '9:28 pm',
#  '9:30 pm',
#  '9:34 pm',
#  '9:35 pm',
#  '9:36 pm',
#  '9:39 pm',
#  '9:40 pm',
#  '9:40 pm',
#  '9:43 pm',
#  '9:56 pm',
#  '9:59 pm',
#  '9:59 pm',
#  '10:14 pm',
#  '10:15 pm',
#  '10:15 pm',
#  '11:18 pm',
#  '6:34 am',
#  '8:17 am',
#  '8:21 am',
#  '10:16 am',
#  '10:17 am',
#  '10:19 am',
#  '10:19 am',
#  '10:20 am',
#  '10:20 am',
#  '10:22 am',
#  '10:22 am',
#  '10:22 am',
#  '10:23 am',
#  '10:25 am',
#  '10:25 am',
#  '10:28 am',
#  '11:17 am',
#  '11:18 am',
#  '11:18 am',
#  '11:18 am',
#  '11:19 am',
#  '11:20 am',
#  '11:20 am',
#  '11:21 am',
#  '11:27 am',
#  '11:28 am',
#  '11:31 am',
#  '12:13 pm',
#  '12:13 pm',
#  '12:13 pm',
#  '12:13 pm',
#  '12:13 pm',
#  '12:13 pm',
#  '1:18 pm',
#  '1:19 pm',
#  '1:20 pm',
#  '1:22 pm',
#  '2:30 pm',
#  '6:52 pm',
#  '6:59 pm',
#  '8:05 pm',
#  '8:06 pm',
#  '8:06 pm',
#  '8:06 pm',
#  '8:10 pm',
#  '8:12 am',
#  '8:12 am',
#  '8:34 am',
#  '9:10 am',
#  '9:11 am',
#  '9:12 am',
#  '9:13 am',
#  '9:13 am',
#  '9:13 am',
#  '9:13 am',
#  '9:13 am',
#  '9:15 am',
#  '9:15 am',
#  '11:44 am',
#  '11:45 am',
#  '11:45 am',
#  '12:21 pm',
#  '2:38 pm',
#  '2:41 pm',
#  '2:41 pm',
#  '2:41 pm',
#  '2:42 pm',
#  '7:12 pm',
#  '9:26 pm',
#  '9:26 pm',
#  '9:26 pm',
#  '9:26 pm',
#  '9:26 pm',
#  '9:27 pm',
#  '9:27 pm',
#  '9:29 pm',
#  '10:18 pm',
#  '12:09 am',
#  '12:09 am',
#  '12:09 am',
#  '12:26 am',
#  '12:26 am',
#  '12:26 am',
#  '12:27 am',
#  '12:30 am',
#  '12:30 am',
#  '8:16 am',
#  '8:17 am',
#  '9:07 am',
#  '9:32 am',
#  '9:55 am',
#  '9:55 am',
#  '9:55 am',
#  '1:26 pm',
#  '1:27 pm',
#  '1:38 pm',
#  '1:44 pm',
#  '1:45 pm',
#  '1:47 pm',
#  '3:26 pm',
#  '3:27 pm',
#  '3:31 pm',
#  '3:42 pm',
#  '3:57 pm',
#  '6:25 pm',
#  '6:27 pm',
#  '6:29 pm',
#  '6:29 pm',
#  '6:29 pm',
#  '6:30 pm',
#  '6:30 pm',
#  '6:32 pm',
#  '6:32 pm',
#  '6:32 pm',
#  '6:33 pm',
#  '6:33 pm',
#  '6:33 pm',
#  '6:34 pm',
#  '7:34 pm',
#  '7:36 pm',
#  '7:36 pm',
#  '7:36 pm',
#  '7:36 pm',
#  '7:36 pm',
#  '7:37 pm',
#  '8:00 pm',
#  '10:05 pm',
#  '10:05 pm',
#  '10:05 pm',
#  '10:05 pm',
#  '10:07 pm',
#  '10:12 pm',
#  '10:13 pm',
#  '10:13 pm',
#  '10:13 pm',
#  '10:13 pm',
#  '10:14 pm',
#  '10:14 pm',
#  '10:14 pm',
#  '10:15 pm',
#  '10:15 pm',
#  '10:17 pm',
#  '10:18 pm',
#  '10:18 pm',
#  '10:19 pm',
#  '10:19 pm',
#  '10:20 pm',
#  '10:21 pm',
#  '10:21 pm',
#  '10:21 pm',
#  '10:21 pm',
#  '10:22 pm',
#  '10:22 pm',
#  '10:23 pm',
#  '10:23 pm',
#  '10:24 pm',
#  '10:24 pm',
#  '10:24 pm',
#  '10:24 pm',
#  '10:26 pm',
#  '10:26 pm',
#  '10:27 pm',
#  '10:27 pm',
#  '10:28 pm',
#  '10:30 pm',
#  '10:30 pm',
#  '10:30 pm',
#  '10:31 pm',
#  '10:31 pm',
#  '10:31 pm',
#  '10:31 pm',
#  '10:33 pm',
#  '10:38 pm',
#  '10:38 pm',
#  '10:39 pm',
#  '10:39 pm',
#  '10:40 pm',
#  '10:40 pm',
#  '10:40 pm',
#  '10:41 pm',
#  '10:41 pm',
#  '10:41 pm',
#  '10:41 pm',
#  '10:41 pm',
#  '10:42 pm',
#  '10:42 pm',
#  '10:42 pm',
#  '10:42 pm',
#  '10:42 pm',
#  '10:43 pm',
#  '10:43 pm',
#  '10:43 pm',
#  '10:43 pm',
#  '10:43 pm',
#  '10:43 pm',
#  '10:44 pm',
#  '10:44 pm',
#  '10:44 pm',
#  '10:44 pm',
#  '10:45 pm',
#  '10:45 pm',
#  '10:45 pm',
#  '10:45 pm',
#  '10:45 pm',
#  '10:45 pm',
#  '10:45 pm',
#  '10:46 pm',
#  '10:47 pm',
#  '10:49 pm',
#  '10:50 pm',
#  '10:50 pm',
#  '10:50 pm',
#  '10:51 pm',
#  '10:51 pm',
#  '10:51 pm',
#  '10:51 pm',
#  '10:51 pm',
#  '10:52 pm',
#  '10:52 pm',
#  '10:52 pm',
#  '10:52 pm',
#  '10:53 pm',
#  '10:53 pm',
#  '10:53 pm',
#  '10:53 pm',
#  '11:40 pm',
#  '11:40 pm',
#  '12:05 am',
#  '12:05 am',
#  '7:20 am',
#  '7:20 am',
#  '7:23 am',
#  '1:11 pm',
#  '7:15 pm',
#  '7:16 pm',
#  '7:16 pm',
#  '7:16 pm',
#  '9:04 pm',
#  '9:21 pm',
#  '9:48 pm',
#  '9:52 pm',
#  '9:55 pm',
#  '11:25 am',
#  '1:36 pm',
#  '1:46 pm',
#  '2:27 pm',
#  '4:56 pm',
#  '4:56 pm',
#  '4:56 pm',
#  '9:22 pm',
#  '11:04 pm',
#  '11:31 pm',
#  '4:33 pm',
#  '4:33 pm',
#  '4:35 pm',
#  '4:35 pm',
#  '4:42 pm',
#  '4:43 pm',
#  '5:48 pm',
#  '5:48 pm',
#  '5:48 pm',
#  '5:49 pm',
#  '5:49 pm',
#  '5:50 pm',
#  '8:52 pm',
#  '8:52 pm',
#  '9:05 pm',
#  '9:06 pm',
#  '9:06 pm',
#  '9:08 pm',
#  '9:08 pm',
#  '9:14 pm',
#  '9:14 pm',
#  '9:14 pm',
#  '9:14 pm',
#  '9:14 pm',
#  '9:15 pm',
#  '9:15 pm',
#  '9:16 pm',
#  '9:17 pm',
#  '9:17 pm',
#  '9:17 pm',
#  '9:17 pm',
#  '9:17 pm',
#  '9:18 pm',
#  '9:18 pm',
#  '9:18 pm',
#  '9:19 pm',
#  '9:20 pm',
#  '9:22 pm',
#  '9:22 pm',
#  '9:22 pm',
#  '9:22 pm',
#  '9:23 pm',
#  '9:24 pm',
#  '9:24 pm',
#  '9:24 pm',
#  '9:25 pm',
#  '9:25 pm',
#  '9:25 pm',
#  '9:26 pm',
#  '9:32 pm',
#  '9:35 pm',
#  '9:35 pm',
#  '9:36 pm',
#  '9:42 am',
#  '9:42 am',
#  '9:42 am',
#  '9:43 am',
#  '9:43 am',
#  '9:55 am',
#  '9:58 am',
#  '10:07 am',
#  '11:09 am',
#  '11:10 am',
#  '3:38 pm',
#  '3:40 pm',
#  '3:40 pm',
#  '3:48 pm',
#  '4:04 pm',
#  '4:04 pm',
#  '4:04 pm',
#  '4:24 pm',
#  '4:40 pm',
#  '4:44 pm',
#  '4:59 pm',
#  '5:15 pm',
#  '5:21 pm',
#  '5:22 pm',
#  '5:23 pm',
#  '5:24 pm',
#  '5:24 pm',
#  '5:24 pm',
#  '5:25 pm',
#  '5:25 pm',
#  '5:32 pm',
#  '5:33 pm',
#  '5:34 pm',
#  '5:34 pm',
#  '5:35 pm',
#  '5:35 pm',
#  '8:33 am',
#  '1:04 pm',
#  '10:58 am',
#  '10:58 am',
#  '10:59 am',
#  '10:59 am',
#  '11:00 am',
#  '11:14 am',
#  '11:16 am',
#  '11:19 am',
#  '11:20 am',
#  '11:21 am',
#  '11:23 am',
#  '11:23 am',
#  '11:23 am',
#  '11:25 am',
#  '11:26 am',
#  '11:26 am',
#  '11:28 am',
#  '11:28 am',
#  '8:16 pm',
#  '8:16 pm',
#  '8:17 pm',
#  '8:24 pm',
#  '8:26 pm',
#  '10:14 pm',
#  '10:39 pm',
#  '10:40 pm',
#  '10:41 pm',
#  '10:42 pm',
#  '10:43 pm',
#  '10:47 pm',
#  '10:48 pm',
#  '10:49 pm',
#  '10:49 pm',
#  '10:50 pm',
#  '10:50 pm',
#  '10:51 pm',
#  '10:51 pm',
#  '10:52 pm',
#  '10:52 pm',
#  '10:53 pm',
#  '2:52 am',
#  '5:32 am',
#  '9:46 am',
#  '10:17 am',
#  '10:18 am',
#  '10:18 am',
#  '4:49 pm',
#  '4:50 pm',
#  '9:20 pm',
#  '9:20 pm',
#  '9:28 pm',
#  '9:32 pm',
#  '11:28 pm',
#  '11:29 pm',
#  '12:38 am',
#  '1:51 am',
#  '1:31 pm',
#  '1:36 pm',
#  ...]

# %%
date = [msgs[i].split(',')[0] for i in range(len(msgs))]
len(date)
# Out:
# 8072

# %%
name = [msgs[i].split('-')[1].split(':')[0] for i in range(len(msgs))]
len(name)
# Out:
# 8072

# %%
content = []
for i in range(len(msgs)):
  try:
    content.append(msgs[i].split(':')[2])
  except IndexError:
    content.append('Missing Text')
len(content)
# Out:
# 8072

# %%
df = pd.DataFrame(list(zip(date, time, name, content)), columns = ['Date', 'Time', 'Name', 'Content'])
df
# Out:
#             Date      Time                                              Name  \
# 0     31/01/2020  11:57 am   Sonia Blade created group "400l physicists⚖📡🗜⚡"
# 1     31/01/2020  11:57 am                                    You were added
# 2     04/02/2020   7:14 am                                      Funmi Lasu 2
# 3     04/02/2020   7:14 am                                      Funmi Lasu 2
# 4     04/02/2020   7:14 am                                      Funmi Lasu 2
# ...          ...       ...                                               ...
# 8067  30/05/2020   8:13 pm                                 +234 803 818 5652
# 8068  30/05/2020   8:19 pm                                             Aisha
# 8069  30/05/2020  10:24 pm                                 +234 803 818 5652
# 8070  30/05/2020  10:45 pm                                 +234 907 255 1409
# 8071  30/05/2020  10:47 pm                                 +234 803 818 5652
#
#                                                 Content
# 0                                          Missing Text
# 1                                          Missing Text
# 2      Will yhu guys jus stop all memes u guys are d...
# 3                                            Sorry dear
# 4                                Make una beta go sleep
# ...                                                 ...
# 8067                                       Thanks banty
# 8068                             Happy birthday tobsfad
# 8069                                       Thanks yisha
# 8070   Happy birthday tobsfad. Wish you long life an...
# 8071                                     Thank you boss
#
# [8072 rows x 4 columns]

# %%
df = df[df["Content"]!='Missing Text']
df.reset_index(inplace=True, drop=True)
df
# Out:
#             Date      Time                Name  \
# 0     04/02/2020   7:14 am        Funmi Lasu 2
# 1     04/02/2020   7:14 am        Funmi Lasu 2
# 2     04/02/2020   7:14 am        Funmi Lasu 2
# 3     04/02/2020   7:14 am        Funmi Lasu 2
# 4     04/02/2020   8:03 am               Aisha
# ...          ...       ...                 ...
# 7990  30/05/2020   8:13 pm   +234 803 818 5652
# 7991  30/05/2020   8:19 pm               Aisha
# 7992  30/05/2020  10:24 pm   +234 803 818 5652
# 7993  30/05/2020  10:45 pm   +234 907 255 1409
# 7994  30/05/2020  10:47 pm   +234 803 818 5652
#
#                                                 Content
# 0      Will yhu guys jus stop all memes u guys are d...
# 1                                            Sorry dear
# 2                                Make una beta go sleep
# 3                                       <Media omitted>
# 4                                  Sorry. Get well soon
# ...                                                 ...
# 7990                                       Thanks banty
# 7991                             Happy birthday tobsfad
# 7992                                       Thanks yisha
# 7993   Happy birthday tobsfad. Wish you long life an...
# 7994                                     Thank you boss
#
# [7995 rows x 4 columns]

# %%
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
df['DateTime']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0      2020-04-02 07:14:00
# 1      2020-04-02 07:14:00
# 2      2020-04-02 07:14:00
# 3      2020-04-02 07:14:00
# 4      2020-04-02 08:03:00
#                ...
# 7990   2020-05-30 20:13:00
# 7991   2020-05-30 20:19:00
# 7992   2020-05-30 22:24:00
# 7993   2020-05-30 22:45:00
# 7994   2020-05-30 22:47:00
# Name: DateTime, Length: 7995, dtype: datetime64[ns]

# %%
df['weekday'] = df['DateTime'].apply(lambda x: x.day_name())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Letter_Count'] = df['Content'].apply(lambda s : len(s))
df['Word_Count'] = df['Content'].apply(lambda s : len(s.split(' ')))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Hour'] = df['Time'].apply(lambda x : x.split(':')[0])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#          Date     Time           Name  \
# 0  04/02/2020  7:14 am   Funmi Lasu 2
# 1  04/02/2020  7:14 am   Funmi Lasu 2
# 2  04/02/2020  7:14 am   Funmi Lasu 2
# 3  04/02/2020  7:14 am   Funmi Lasu 2
# 4  04/02/2020  8:03 am          Aisha
#
#                                              Content            DateTime  \
# 0   Will yhu guys jus stop all memes u guys are d... 2020-04-02 07:14:00
# 1                                         Sorry dear 2020-04-02 07:14:00
# 2                             Make una beta go sleep 2020-04-02 07:14:00
# 3                                    <Media omitted> 2020-04-02 07:14:00
# 4                               Sorry. Get well soon 2020-04-02 08:03:00
#
#     weekday  Letter_Count  Word_Count Hour
# 0  Thursday           122          29    7
# 1  Thursday            11           3    7
# 2  Thursday            23           6    7
# 3  Thursday            16           3    7
# 4  Thursday            21           5    8

# %%
df.to_csv("WhatsappChat.csv")
